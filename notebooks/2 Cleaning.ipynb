# %%
import pymongo
import pandas as pd
import numpy as np
import json

from tqdm import tqdm
from bson import json_util 

from bs4 import BeautifulSoup
import unicodedata
import re
from text_utils import cleaning
from text_utils.metrics import get_chunks_info

# %% [markdown]
# ## Load Data from DB

# %%
import os
import yaml

with open("config.yaml", "r") as ymlfile:
    settings = yaml.safe_load(ymlfile)


isRemote = False


try:
    if (isRemote):
        client = pymongo.MongoClient(host = settings['mongo-remote']['host'],
                                     port = settings['mongo-remote']['port'],
                                     username = settings['mongo-remote']['user'],
                                     password = settings['mongo-remote']['pw'],
                                     authMechanism= settings['mongo-remote']['authMechanism'])
        client.server_info()  # force connection on a request as the
        # connect=True parameter of MongoClient seems
        # to be useless here
    else:
        client = pymongo.MongoClient("mongodb://localhost:27017/")
        client.server_info()  # force connection on a request as the
    # connect=True parameter of MongoClient seems
    # to be useless here
except pymongo.errors.ServerSelectionTimeoutError as err:
    # do whatever you need
    print(err)

# %%
db = client["parliament"]
articles = db["articles"]

# %%
mongo_df = pd.DataFrame.from_records(articles.find())
mongo_df.head()
# Out:
#                         _id  \
# 0  5d27eca6172d9aa762d4802f
# 1  5d27eca6172d9aa762d48030
# 2  5d27eca6172d9aa762d48031
# 3  5d27eca6172d9aa762d48032
# 4  5d27eca6172d9aa762d48033
#
#                                         article_text  \
# 0  <p>[(proc text) Debate resumed. (proc text)]</...
# 1  <p class="ql-align-justify">4 <strong>Mr Vikra...
# 2  <p class="ql-align-justify">8 <strong>Assoc Pr...
# 3  <p>5 <strong>Ms Irene Quay Siew Ching</strong>...
# 4  <p class="ql-align-justify">2 <strong>Mr Lim B...
#
#                                               chunks  \
# 0  [{'content': '[(proc text) Debate resumed. (pr...
# 1  [{'content': 'Mr Vikram Nair asked the Ministe...
# 2  [{'content': 'Assoc Prof Walter Theseira asked...
# 3  [{'content': 'Ms Irene Quay Siew Ching asked t...
# 4  [{'content': 'Mr Lim Biow Chuan asked the Depu...
#
#                                         cleaned_join     dominant_topic  \
# 0  [(proc text) Debate resumed. (proc text)]<br/>...            Society
# 1  Mr Vikram Nair asked the Minister for Foreign ...            Society
# 2  Assoc Prof Walter Theseira asked the Minister ...  Internal Security
# 3  Ms Irene Quay Siew Ching asked the Minister fo...        Environment
# 4  Mr Lim Biow Chuan asked the Deputy Prime Minis...         Employment
#
#                                           html_clean  parliament_num  \
# 0  [[(proc text) Debate resumed. (proc text)], Mr...              13
# 1  [Mr Vikram Nair asked the Minister for Foreign...              13
# 2  [Assoc Prof Walter Theseira asked the Minister...              13
# 3  [Ms Irene Quay Siew Ching asked the Minister f...              13
# 4  [Mr Lim Biow Chuan asked the Deputy Prime Mini...              13
#
#                                         parsed_convo  \
# 0  [{'content': '[(proc text) Debate resumed. (pr...
# 1  [{'content': 'Mr Vikram Nair asked the Ministe...
# 2  [{'content': 'Assoc Prof Walter Theseira asked...
# 3  [{'content': 'Ms Irene Quay Siew Ching asked t...
# 4  [{'content': 'Mr Lim Biow Chuan asked the Depu...
#
#                                     persons_involved  session_num  \
# 0  [The Minister for Law, Mr Darryl David, Mr Lou...            2
# 1  [The Minister for Foreign Affairs, Mr Vikram N...            2
# 2  [Ms Low Yen Ling, Assoc Prof Walter Theseira, ...            2
# 3  [The Senior Minister of State for Health, Ms I...            2
# 4  [Ms Indranee Rajah, Mr Lim Biow Chuan, The Sec...            2
#
#            session_type sitting_date  sitting_num  \
# 0  SECOND READING BILLS   2019-05-08          105
# 1          ORAL ANSWERS   2019-05-08          105
# 2          ORAL ANSWERS   2019-05-08          105
# 3          ORAL ANSWERS   2019-05-08          105
# 4          ORAL ANSWERS   2019-05-08          105
#
#                                              src_url  \
# 0  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 1  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 2  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 3  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 4  https://sprs.parl.gov.sg/search/sprs3topic?rep...
#
#                                                title  volume_num
# 0  PROTECTION FROM ONLINE FALSEHOODS AND MANIPULA...          94
# 1  STATE OF BILATERAL RELATIONS WITH MALAYSIA FOL...          94
# 2  COMPANIES WITH MEASURES TO DEAL WITH WORKPLACE...          94
# 3  REVIEW OF DRUG TESTING STANDARDS IN SINGAPORE ...          94
# 4  LIVING IN PRIVATE PROPERTIES BUT WITH NO DECLA...          94

# %%
# %time mongo_df['chunks'] = mongo_df.article_text.map( lambda x : get_chunks_info(x,verbose=False))
# Out:
# CPU times: user 3min 15s, sys: 4.17 s, total: 3min 19s
# Wall time: 3min 46s

# %%
# %time mongo_df['parsed_convo'] = mongo_df.chunks.map(lambda x : cleaning.parse_topics(x))
# Out:
# CPU times: user 337 ms, sys: 486 ms, total: 823 ms
# Wall time: 837 ms

# %%
# %time mongo_df['html_clean'] = mongo_df.article_text.map(cleaning.parse_hansard_text)
# Out:
# CPU times: user 2min 41s, sys: 2.42 s, total: 2min 44s
# Wall time: 2min 46s

# %%
# %time mongo_df['cleaned_join'] = mongo_df.html_clean.map(lambda x : "<br/>".join(x))
# Out:
# CPU times: user 83.5 ms, sys: 131 ms, total: 215 ms
# Wall time: 219 ms

# %%
# %time mongo_df['persons_involved'] = mongo_df.chunks.map(lambda x : cleaning.get_entities(x))
# Out:
# CPU times: user 101 ms, sys: 4.4 ms, total: 105 ms
# Wall time: 108 ms

# %%
for row in tqdm(mongo_df.itertuples()):
    query = { "_id" : row._1}
    value = { "$set": { "chunks": json_util.dumps(row.chunks),
                       "parsed_convo" : row.parsed_convo,
                       "persons_involved" : row.persons_involved,
                      "html_clean": row.html_clean,
                      "cleaned_join": row.cleaned_join}}
    articles.update_one(query,value)
# Out:
# 9531it [00:18, 527.12it/s]

# %%
mongo_df = pd.DataFrame.from_records(articles.find())
# Out:
#                         _id  \
# 0  5d27eca6172d9aa762d4802f
# 1  5d27eca6172d9aa762d48030
# 2  5d27eca6172d9aa762d48031
# 3  5d27eca6172d9aa762d48032
# 4  5d27eca6172d9aa762d48033
#
#                                         article_text  \
# 0  <p>[(proc text) Debate resumed. (proc text)]</...
# 1  <p class="ql-align-justify">4 <strong>Mr Vikra...
# 2  <p class="ql-align-justify">8 <strong>Assoc Pr...
# 3  <p>5 <strong>Ms Irene Quay Siew Ching</strong>...
# 4  <p class="ql-align-justify">2 <strong>Mr Lim B...
#
#                                               chunks  \
# 0  {"0": {"entity": "NA", "content": "[(proc text...
# 1  {"0": {"entity": "NA", "content": "Mr Vikram N...
# 2  {"0": {"entity": "NA", "content": "Assoc Prof ...
# 3  {"0": {"entity": "NA", "content": "Ms Irene Qu...
# 4  {"0": {"entity": "NA", "content": "Mr Lim Biow...
#
#                                         cleaned_join     dominant_topic  \
# 0  [(proc text) Debate resumed. (proc text)]<br/>...            Society
# 1  Mr Vikram Nair asked the Minister for Foreign ...            Society
# 2  Assoc Prof Walter Theseira asked the Minister ...  Internal Security
# 3  Ms Irene Quay Siew Ching asked the Minister fo...        Environment
# 4  Mr Lim Biow Chuan asked the Deputy Prime Minis...         Employment
#
#                                           html_clean  parliament_num  \
# 0  [[(proc text) Debate resumed. (proc text)], Mr...              13
# 1  [Mr Vikram Nair asked the Minister for Foreign...              13
# 2  [Assoc Prof Walter Theseira asked the Minister...              13
# 3  [Ms Irene Quay Siew Ching asked the Minister f...              13
# 4  [Mr Lim Biow Chuan asked the Deputy Prime Mini...              13
#
#                                         parsed_convo  \
# 0  [{'content': '[(proc text) Debate resumed. (pr...
# 1  [{'content': 'Mr Vikram Nair asked the Ministe...
# 2  [{'content': 'Assoc Prof Walter Theseira asked...
# 3  [{'content': 'Ms Irene Quay Siew Ching asked t...
# 4  [{'content': 'Mr Lim Biow Chuan asked the Depu...
#
#                                     persons_involved  session_num  \
# 0  [Prof Lim Sun Sun, Miss Cheng Li Hui, An hon M...            2
# 1  [Mr Speaker, Assoc Prof Walter Theseira, Mr Vi...            2
# 2  [Ms Anthea Ong, Assoc Prof Walter Theseira, Ms...            2
# 3  [Ms Irene Quay Siew Ching, Dr Lam Pin Min, The...            2
# 4  [The Second Minister for Finance, Mr Lim Biow ...            2
#
#            session_type sitting_date  sitting_num  \
# 0  SECOND READING BILLS   2019-05-08          105
# 1          ORAL ANSWERS   2019-05-08          105
# 2          ORAL ANSWERS   2019-05-08          105
# 3          ORAL ANSWERS   2019-05-08          105
# 4          ORAL ANSWERS   2019-05-08          105
#
#                                              src_url  \
# 0  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 1  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 2  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 3  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 4  https://sprs.parl.gov.sg/search/sprs3topic?rep...
#
#                                                title  volume_num
# 0  PROTECTION FROM ONLINE FALSEHOODS AND MANIPULA...          94
# 1  STATE OF BILATERAL RELATIONS WITH MALAYSIA FOL...          94
# 2  COMPANIES WITH MEASURES TO DEAL WITH WORKPLACE...          94
# 3  REVIEW OF DRUG TESTING STANDARDS IN SINGAPORE ...          94
# 4  LIVING IN PRIVATE PROPERTIES BUT WITH NO DECLA...          94

# %%
mongo_df.iloc[5].chunks
# Out:
# '{"0": {"entity": "NA", "content": "Mr Louis Ng Kok Kwang asked the Minister for Health (a) what is the rationale behind barring women above 45 years old from receiving in-vitro fertilisation (IVF) treatments in Singapore; (b) what is the rationale behind limiting the number of IVF fresh cycles for women above 40 years old; and (c) whether the Ministry is planning to review these restrictions."}, "1": {"entity": "The Senior Minister of State for Health (Dr Amy Khor Lean Suan) (for the Minister for Health)", "content": " The success rates of Assisted Reproduction (AR) procedures decrease and the likelihood of medical complications and adverse pregnancy outcomes increases with maternal age. It is therefore important that patients are well informed of the risks and outcomes of such procedures.To protect patients\\u2019 interests, the current age limit for AR procedures, including in-vitro fertilisation (IVF), is set at age 45. However, MOH considers appeals on a case-by-case basis. In addition, the current IVF limit is set at 10 fresh cycles for women aged 40 and below, and five fresh cycles for women above 40. This is because there are increased clinical risks with multiple cycles of ovarian stimulation and oocyte retrieval. These risks include ovarian hyper-stimulation syndrome (OHSS), bleeding and infection. We recognise that recent advancements in AR technology have improved safety of AR procedures in general. The Government reviews these limits regularly and will take into account such technological advancements and other medical and social considerations, including the risk of chronic diseases, pregnancy or delivery complications, and continued low success rates of pregnancy and live births for women of higher maternal age."}, "2": {"entity": "Mr Louis Ng Kok Kwang (Nee Soon)", "content": " I thank the Senior Minister of State for the reply. I understand the concerns and risks that she mentioned but I think these are concerns and risks that parents should consider and decide whether they want to have a child, and not something that the Government should decide.So, two clarifications. One, whether MOH will review this policy of restricting the number of IVF cycles after 40 and restricting IVF completely after 45; and, two, how long will such a review take?"}, "3": {"entity": "Dr Amy Khor Lean Suan", "content": " Let me say that besides Singapore, some countries like Belgium and Israel also impose AR age limits due to medical and social concerns of pregnancy and child-bearing at older ages.In Singapore, the current AR age limit of 45 is set based on empirical evidence that shows that the chances of conception are very low at older ages. In fact, for AR success rates, it falls sharply at age 40, from 17.1% for women of ages between 35 to 39, to less than 7% for women from age 40 to 44. And then it falls further to about 4% for women aged 45 and above. In addition, there are also increased medical risks and complications as well as adverse pregnancy outcomes for women of older ages. As I have said in my reply, this is really set to protect the patients\' interests. Nonetheless, MOH does consider appeals on a case-by-case basis.For the treatment cycle limit of five fresh cycles for women above the age of 40, again this is due to concerns of increased clinical risks with older ages, with multiple cycles of ovarian stimulation and oocyte retrieval. Notwithstanding this, as I have also said, we recognise that there have been recent advancements made in AR technology that have actually improved the safety of AR procedures in general, we regularly review these limits and will take into account such technological advancements as well as professional standards of care and other patient factors. It is an on-going review, so we will make the announcements if we decide to change these limits."}, "4": {"entity": "Mr Louis Ng Kok Kwang", "content": " I just want to make one point. I understand the policy intent but what all this is driving  ...
