# %% [markdown]
# # Scrape Singapore Hansard
#
# ## Import Libraries

# %%
from bs4 import BeautifulSoup
import re
import os
import datetime
import numpy as np
from time import sleep, process_time
import pandas
import random
from datetime import date 
import requests


from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException,ElementNotInteractableException
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from json import JSONDecodeError

from db.models import Link, Article, mp_record, MpResponse, \
    MemParliament, ApptRecord, CommitteeRecord, \
    ConstituencyRecord, postgres_engine
from db.db_utils import get_or_create

from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry


session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

from multiprocessing import Pool, TimeoutError

# %%
title = "Protection from Online Falsehoods and Manipulation Bill"
url = "https://sprs.parl.gov.sg/search/sprs3topic?reportid=bill-367" 
sitting_date = "8-5-2019"

# %%
def parse_sittingdate(subtext):
    
    sitting_date = [int(k) for k in re.search(r"(?<=\:)(.*?)(?=\,)", subtext).group(0).strip().split('-')]
    d = date(sitting_date[2],sitting_date[1],sitting_date[0])
    
    return d

parse_sittingdate("Sitting Date: 8-5-2019 , Vol:94")
# Out:
# datetime.date(2019, 5, 8)

# %%
url = "https://sprs.parl.gov.sg/search/sprs3topic?reportid=oral-answer-1987"
re.findall(r'(?<=sprs3topic\?reportid=).*', url)[0]
# Out:
# 'oral-answer-1987'

# %%
url_old_1 = "https://sprs.parl.gov.sg/search/topic?reportid=030_20110214_S0007_T0002"
url = "https://sprs.parl.gov.sg/search/topic?reportid=034_20120116_S0015_T0004"
url_old = "https://sprs.parl.gov.sg/search/topic?reportid=020_20110411_S0004_T0002" #with changes to API
res_t = re.findall(r'(?<=\?reportid=).*', url_old)[0]

def parse_res_old(res):
    uri = "https://sprs.parl.gov.sg/search/getHansardTopic/?id=" + res
    code = int(session.post(uri).status_code)
    
    
    if code==200:
        result = session.post(uri).json()['htmlContent']
        b = BeautifulSoup(result,'lxml')
        raw = b.get_text()
        d = b.find_all('meta',{'name':"Parl_No"}) ## check which API it belongs under
        if d: ## for deprecated API (old v1)
            session_type = b.find('meta',{'name':"Sect_Name"})['content']
            sitting_num = int(re.findall(r'(?s)(?<=Sitting No:)(\d+?)(?=\nSitting Date|\Sitting Date)',raw)[0].strip())
            session_num = b.find('meta',{'name':"Sess_No"})['content']
            parliament_num = b.find('meta',{'name':"Parl_No"})['content']
            volume_num = b.find('meta',{'name':"Vol_No"})['content']
            article_text = re.findall(r'(?s)(?<=<div align="left">).*?(?=<\/html>)',str(b))[0]
            return session_type,sitting_num,session_num,parliament_num,volume_num,article_text
        else:
            ## for recent API (old v2)
#             raw = b.get_text()
            title = re.findall(r'(?s)(?<=Title:).*?(?=MPs)',raw)[0].strip().replace('\r\n',' ')
            exclude = ['Assent to Bills Passed','Administration of Oaths']

            if title not in exclude:
                session_type = str(re.findall(r'(?<=Section Name:)(.*?)(?=Title)',raw)[0].strip())
                sitting_num = int(re.findall(r'(?<=Sitting No:)(.*?)(?=Sitting)',raw)[0].strip())
                session_num = int(re.findall(r'(?<=Session No:)(.*?)(?=Volume)',raw)[0].strip())
                parliament_num = int(re.findall(r'(?<=Parliament No:)(.*?)(?=Session)',raw)[0].strip())
                volume_num = int(re.findall(r'(?<=Volume No:)(.*?)(?=Sitting)',raw)[0].strip())
                article_text = str(b.find("div", class_ = "body hansardBaseBody hansardContenteBody"))
            else:
                session_type = title
                sitting_num = int(re.findall(r'(?<=Sitting No:)(.*?)(?=Sitting)',raw)[0].strip())
                session_num = int(re.findall(r'(?<=Session No:)(.*?)(?=Volume)',raw)[0].strip())
                parliament_num = int(re.findall(r'(?<=Parliament No:)(.*?)(?=Session)',raw)[0].strip())
                volume_num = int(re.findall(r'(?<=Volume No:)(.*?)(?=Sitting)',raw)[0].strip())
                article_text = str(b.find("div", class_ = "body hansardBaseBody hansardContenteBody"))

            return session_type,sitting_num,session_num,parliament_num,volume_num,article_text
    else:
        raise ValueError
    
parse_res_old(res_t)
# Out:
# ('BILLS',
#  27,
#  '2',
#  '11',
#  '87',
#  '<span style="FONT-SIZE: 13pt; FONT-FAMILY: \'Times New Roman\'"><p>\xa0</p><p></p><p>\xa0\xa0\xa0\xa0 Order for Second Reading read.<br/>\n</p>\n<p>\xa0</p>\n<p>2.48 pm</p>\n<p>\xa0</p><p>\xa0\xa0\xa0\xa0\xa0<b>Mr Lim Hng Kiang:</b> \xa0Sir, I beg to move, "That the Bill be now read a Second time."\r\n\r\n</p><p><br/>\r\n\xa0\xa0\xa0\xa0 This Bill enhances existing protection schemes for depositors and insurance policy owners, and brings them together into a single piece of legislation.\xa0 The Deposit Insurance Act which established the Deposit Insurance\xa0(DI) Scheme, as well as provisions under the Insurance Act relating to the Policy Owners\' Protection (PPF) Scheme, will be repealed as a result.</p>\n<p><br/>\r\n\xa0\xa0\xa0\xa0 The proposed enhancements in this Bill will strengthen the protection of depositors and owners of insurance policies.\xa0 In developing the enhancements, MAS consulted the industry and the public and, where appropriate, incorporated their feedback in the key features of the Schemes.\xa0 MAS also took into consideration lessons learned internationally during the recent global financial crisis.</p>\n<p><br/>\r\n\xa0\xa0\xa0\xa0 Mr Speaker, Sir, I will first provide some background to the existing DI and PPF schemes.</p>\n<p><br/>\r\n\xa0\xa0\xa0\xa0 The DI Scheme in Singapore was implemented in 2006.\xa0 It aimed to provide a basic level of protection to small depositors.\xa0 A DI Fund, built up through regular contributions levied on the full banks and finance companies who are Scheme members, would help ensure that depositors can receive quick compensation on their deposits up to the coverage limit without having to wait for the outcome of the Scheme member\'s liquidation process.\xa0 The Scheme was also designed to keep the cost of providing deposit insurance manageable, while preserving incentives for large depositors to continue to exercise market discipline.</p>\n<p><br/>\r\n\xa0\xa0\xa0\xa0 At present, the DI Scheme insures Singapore dollar deposits of individuals and charities in current, savings and fixed deposit accounts held with a full bank or finance company, up to S$20,000 per insured depositor per Scheme member.\xa0 This was sufficient to fully cover 86% of insured depositors when the Scheme was first designed, which was within international norms of 80% to 90%.\xa0</p>\n<p><br/>\r\n\xa0\xa0\xa0\xa0 A separate scheme – the Policy Owners\' Protection (PPF) Scheme – exists to protect insurance policy owners.\xa0 The PPF Scheme is provided for in the Insurance Act to compensate policy owners of life policies and compulsory insurance policies in the event that their insurer fails.\xa0 The existing PPF Scheme covers 90% of the liabilities for life policies and 100% of the liabilities for compulsory insurance policies.\xa0 The Scheme is currently post-funded.\xa0 This means that PPF levies will be collected from PPF member insurers only when there is a payout following the failure of an insurer.</p>\n<p><br/>\r\n\xa0\xa0\xa0\xa0 The PPF Scheme provides policy owners with certainty as to how much of their policy monies will be protected and also whether the losses they have incurred from insured events will be compensated, should their insurer fail.\xa0 Besides alleviating financial distress to individual policy owners, the PPF Scheme supports public confidence in the insurance industry and helps limit possible disruption to the economy.\xa0</p>\n<p><br/>\r\n\xa0\xa0\xa0\xa0 To ensure that the DI and PPF Schemes continue to provide adequate protection to depositors and policy owners, several enhancements are proposed.\xa0 Mr Speaker, Sir, I will now go through the key provisions of this Bill.</p>\n<p>\xa0</p>\n<p></p>\n<p><i>DI Scheme-Coverage</i></p>\n<p><br/>\r\n\xa0\xa0\xa0\xa0 There are two main changes to the deposit insurance coverage.\xa0 First, the coverage of the Scheme will be expanded from insuring only individuals and charities to insuring all non-bank depositors.\xa0 This mea ...

# %%
url = "https://sprs.parl.gov.sg/search/sprs3topic?reportid=written-answer-na-962"
res_t = re.findall(r'(?<=\?reportid=).*', url)[0]

def parse_res(res):
    uri = "https://sprs.parl.gov.sg/search/getHansardTopic/?id=" + res
    result = session.post(uri).json()
    r_type = result['type']
    
    if r_type !='atbp':
        w = result['resultHTML']
        session_type = w['reportType']
        sitting_num = w['sittingNo']
        session_num = w['sessionNo']
        parliament_num = w['parlNo']
        volume_num = w['volumeNo']
        article_text = w['content']
        return session_type,sitting_num,session_num,parliament_num,volume_num,article_text
    else:
        w = result['resultData']
        session_type = r_type
        sitting_num = w['sittingNo']
        session_num = w['sessionNo']
        parliament_num = w['parlNo']
        volume_num = w['volumeNo']
        article_text = str(w['atbpList'])
        return session_type,sitting_num,session_num,parliament_num,volume_num,article_text
    

parse_res(res_t)
# Out:
# ('Written Answers to Questions for Oral Answer Not Answered by 3.00 pm',
#  '7',
#  '1',
#  '12',
#  '89',
#  '<p>30 <strong>Mr R Dhinakaran</strong> asked the Acting Minister for Community Development, Youth and Sports if it will be timely to consider shifting the responsibility of childcare and pre-school education to the Ministry of Education since the Ministry of Community Development, Youth and Sports is undergoing a restructuring, so that there is a better fit.</p><p><strong>Mr Chan Chun Sing</strong>: While the pre-school sector is currently overseen by two Ministries, MOE and MCYS have coordinated closely in key policy areas, especially at the kindergarten level. These include requiring the same qualifications for principals and teachers teaching children aged four to six, and adopting the Singapore Pre-school Accreditation Framework (SPARK) for both kindergartens and childcare centres.</p><p>As recently announced, the Government will be setting up a new statutory board to oversee early childhood education and care for pre-school children across the age ranges. The statutory board will be responsible for the development and regulation of the pre-school sector, covering both kindergartens and childcare centres. It will serve as a single focal point to drive quality, accessibility and affordability improvements in the sector.</p><p>MOE and the new Ministry of Social and Family Development will work closely together on the formation of the new statutory board. More details will be announced in due course.</p>')

# %%
def assign_parser(url):
    res = re.findall(r'(?<=\?reportid=).*', url)[0]
    if 'sprs3topic' in url:
        return parse_res(res)
    else:
        return parse_res_old(res)

# %%
assign_parser('https://sprs.parl.gov.sg/search/topic?reportid=030_20110214_S0007_T0002')
# Out:
# ('ORAL ANSWERS TO QUESTIONS NOT REACHED',
#  16,
#  '2',
#  '11',
#  '87',
#  ' <p><span style="FONT-SIZE: 13pt; FONT-FAMILY: \'Times New Roman\'">\xa0\xa0\xa0\xa0\xa022.</span>\xa0\xa0\t        <!--MP_NAME:Assoc. Prof. Paulin Tay Straughan--><span style="FONT-SIZE: 13pt; FONT-FAMILY: \'Times New Roman\'"><b>Assoc. Prof. Paulin Tay Straughan </b>asked the Minister for Manpower if he can provide data on (a) the proportion of employers aside from the Civil Service that offer paternity leave and unrecorded childcare leave as part of employee benefits; and (b) the proportion of unrecorded childcare leave that is taken by fathers.</span></p> <span style="FONT-SIZE: 13pt; FONT-FAMILY: \'Times New Roman\'"><!--MP_NAME:Mr Gan Kim Yong--><p align="left">\xa0\xa0\xa0\xa0\xa0<b>Mr Gan Kim Yong:</b></p><p>\xa0\xa0\xa0\xa0\xa0\xa0 Even though paternity leave is not specifically legislated, MOM’s survey showed that about 48% of private sector establishments with at least 25 employees provided paternity leave last year.</p><p>\xa0</p><p>\xa0\xa0\xa0\xa0 In addition, all working fathers of Singaporean children enjoy six days of paid childcare leave for children aged up to seven years old and six days of unpaid infant care leave for children aged up to two years old as provided for under the Children Development Co-Savings Act (CDCA). On the proportion of paid childcare leave taken by fathers, in 2009, there were more than 25,000 claims made in respect of Government-paid childcare leave taken by fathers, just slightly below the 27,000 claims for mothers. Last year, about two in\xa010 (about 19%) private sector establishments also provided childcare sick leave beyond the legal requirements.</p><p>\xa0</p><p>\xa0\xa0\xa0\xa0 Anecdotally, companies may also provide flexible work arrangements or allow working parents to take time-off on an informal basis for them to attend to the needs of their children. However, as such work arrangements are non-statutory, and usually arranged under mutual agreement between the employer and employee, we do not have data on the take-up by working fathers.</p></span> <div align="center"><span font-family:="" new="" roman="" style=\'\\"FONT-SIZE:\'><b> </b></span></div></div></body>')

# %%
HANSARD_URL = "https://sprs.parl.gov.sg/search/home"

# Firefox session


today_date = datetime.datetime.today()
parse_date = today_date.strftime("%Y-%m-%d")
timeout=5

def fetch_links():
    
    
    driver = webdriver.Firefox(executable_path='./geckodriver-osx')
    url = HANSARD_URL
    driver.get(url)
    assert "Search" in driver.title
    sleep(2)
    try:
        date_range = driver.find_element_by_class_name("date-range")
        Select(date_range.find_element_by_class_name("form-control")).select_by_visible_text('Specified range')
        sleep(1)
        
        # Specify Time Range
        Select(driver.find_element_by_id("fromday")).select_by_visible_text('1')
        Select(driver.find_element_by_id("frommonth")).select_by_visible_text('1')
        Select(driver.find_element_by_id("fromyear")).select_by_visible_text('1995')
        Select(driver.find_element_by_id("today")).select_by_visible_text('12')
        Select(driver.find_element_by_id("tomonth")).select_by_visible_text('3')
        Select(driver.find_element_by_id("toyear")).select_by_visible_text('2004')
        
        # Go to search results
        driver.find_element_by_css_selector(".btn-black[label='Search']").click()
        driver.switch_to_window(driver.window_handles[-1])       
        sleep(5)
        print(f"Current URL : {driver.current_url}")
        query_result = driver.find_element_by_class_name("showingResults").text
        
        
        num_results = int(re.search("\w+$", query_result).group(0))
        # curr_cnt = initial_cnt
        page_cnt = 1
        link_cnt = 1
        print("\n ////////////////// NEW PAGE //////////////////////// \n")
        print("Number of results : {}".format(query_result))
        while link_cnt <= num_results:
            if page_cnt > 1 :
                sleep(1)
                print("\n ////////////////// NEW PAGE //////////////////////// \n")
                print("Number of results so far : {}".format(link_cnt))

            print("Current page count: {}".format(page_cnt))
            # curr_cnt = int(re.findall(r"\d+(?![of])", query_result)[1])
            results = driver.find_elements_by_tag_name("tbody")
            result_idx = 0
#             print(results)
            while result_idx < len(results):
                try:
                    sleep(3)
                    print(f"Current ID = {result_idx}")
                    print("Processing")
                    result = results[result_idx]
                    title = result.find_element_by_tag_name("a").text # get report name
                    sub_text = result.find_element_by_tag_name("i").text # get subtext 

                    result.find_element_by_tag_name("a").click() # opens a new tab 

                    driver.switch_to_window(driver.window_handles[-1])
                    sleep(3)
                    current_url = driver.current_url
                    while current_url == 'about:blank':
                        print("blank url, retrying")
                        sleep(2)
                        current_url = driver.current_url

                    source = driver.page_source
                    res_url = re.findall(r'(?<=\?reportid=).*', current_url)[0]
                    print(f"Current URL : {driver.current_url}, Resource = {res_url}")
                    
                    session_type,sitting_num,session_num,parliament_num,volume_num,article_text = assign_parser(current_url)

                    link_entry = get_or_create(Link, title=title, res_url=res_url,
                                               src_url=current_url, 
                                               sitting_date=parse_sittingdate(sub_text))

                    get_or_create(Article,link_article=link_entry,parliament_num=parliament_num,
                                                           volume_num=volume_num,
                                                           sitting_num=sitting_num,
                                                           session_num=session_num,
                                                           session_type=session_type,
                                                           article_text=article_text
                                                          )
#                   
                    result_idx += 1
                    link_cnt+=1
                    driver.close()
                    sleep(random.randint(1,3))
                    driver.switch_to_window(driver.window_handles[-1])
                except IndexError:
                    print("Index of JSON not found,skipping")
                    sleep(1)
                    result_idx += 1
                    link_cnt+=1
                    driver.close()
                    sleep(random.randint(1,3))
                    driver.switch_to_window(driver.window_handles[-1])
                    continue
                except ElementNotInteractableException:
                    print(f"No Element Exists at {result_idx}, go to next")
                    result_idx += 1
                    link_cnt+=1
                    sleep(5)
                    continue
                except NoSuchElementException:
                    print(f"No Element Exists at {result_idx}, go to next")
                    result_idx += 1
                    link_cnt+=1
                    sleep(5)
                    continue
                except JSONDecodeError:
                    print(f"JSON Error on:{res_url} , retrying")
                    driver.close()
                    sleep(random.randint(1,3))
                    driver.switch_to_window(driver.window_handles[-1])
                    pass
                except AttributeError:
                    print(f"JSON not found at {result_idx}, go to next")
                    result_idx += 1
                    link_cnt+=1
                    driver.close()
                    sleep(random.randint(1,3))
                    driver.switch_to_window(driver.window_handles[-1])
                    sleep(5)
                    continue
                except ValueError:
                    print(f"Value Error on:{res_url} , skipping")
                    result_idx += 1
                    link_cnt+=1
                    driver.close()
                    sleep(random.randint(1,3))
                    driver.switch_to_window(driver.window_handles[-1])
                    continue
                    
                    
            page_cnt+=1
            sleep(4)
            next_btn = driver.find_element_by_class_name("fa-angle-right")
            if (next_btn):
                next_btn.click()
                sleep(random.randint(1,3))
            else:
                break

    except Exception as e:
        driver.save_screenshot('error.png')
        print(str(e))
    except KeyboardInterrupt:
        return source
    finally:
        print("Total of {} links processed".format(link_cnt))
        driver.quit()

# %%
# %%timeit
src = fetch_links()
# Out:
# /Users/syamil/anaconda3/envs/pivot/lib/python3.7/site-packages/ipykernel_launcher.py:33: DeprecationWarning: use driver.switch_to.window instead
# Current URL : https://sprs.parl.gov.sg/search/result
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results : Showing results 1 to 20 of 3877
# Current page count: 1
# Current ID = 0
# Processing
# /Users/syamil/anaconda3/envs/pivot/lib/python3.7/site-packages/ipykernel_launcher.py:67: DeprecationWarning: use driver.switch_to.window instead
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040312_S0003_T0002, Resource = 004_20040312_S0003_T0002
# /Users/syamil/anaconda3/envs/pivot/lib/python3.7/site-packages/ipykernel_launcher.py:97: DeprecationWarning: use driver.switch_to.window instead
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20040312_S0003_T0003, Resource = 006_20040312_S0003_T0003
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040312_S0003_T0004, Resource = 005_20040312_S0003_T0004
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040312_S0004_T0001, Resource = 007_20040312_S0004_T0001
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20040312_S0003_T0001, Resource = 003_20040312_S0003_T0001
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040311_S0003_T0004, Resource = 007_20040311_S0003_T0004
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20040311_S0003_T0003, Resource = 006_20040311_S0003_T0003
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040311_S0003_T0006, Resource = 005_20040311_S0003_T0006
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20040311_S0003_T0005, Resource = 008_20040311_S0003_T0005
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040311_S0003_T0002, Resource = 004_20040311_S0003_T0002
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20040311_S0004_T0001, Resource = 009_20040311_S0004_T0001
# Current ID = 11
# Processing
# No Element Exists at 11, go to next
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040310_S0003_T0002, Resource = 007_20040310_S0003_T0002
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20040310_S0003_T0006, Resource = 013_20040310_S0003_T0006
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20040310_S0003_T0004, Resource = 010_20040310_S0003_T0004
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20040310_S0004_T0005, Resource = 008_20040310_S0004_T0005
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20040310_S0003_T0007, Resource = 012_20040310_S0003_T0007
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20040310_S0003_T0005, Resource = 011_20040310_S0003_T0005
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20040310_S0003_T0003, Resource = 009_20040310_S0003_T0003
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040310_S0004_T0002, Resource = 004_20040310_S0004_T0002
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 21
# Current page count: 2
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040310_S0004_T0004, Resource = 005_20040310_S0004_T0004
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20040310_S0004_T0003, Resource = 006_20040310_S0004_T0003
# Current ID = 2
# Processing
# No Element Exists at 2, go to next
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20040310_S0003_T0001, Resource = 014_20040310_S0003_T0001
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040309_S0003_T0001, Resource = 005_20040309_S0003_T0001
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040309_S0005_T0003, Resource = 004_20040309_S0005_T0003
# Current ID = 6
# Processing
# No Element Exists at 6, go to next
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040309_S0005_T0002, Resource = 007_20040309_S0005_T0002
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20040309_S0005_T0001, Resource = 008_20040309_S0005_T0001
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20040308_S0004_T0002, Resource = 008_20040308_S0004_T0002
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040308_S0004_T0003, Resource = 007_20040308_S0004_T0003
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20040308_S0004_T0001, Resource = 009_20040308_S0004_T0001
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20040308_S0003_T0001, Resource = 006_20040308_S0003_T0001
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040308_S0005_T0003, Resource = 005_20040308_S0005_T0003
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20040308_S0005_T0001, Resource = 003_20040308_S0005_T0001
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040308_S0005_T0002, Resource = 004_20040308_S0005_T0002
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20040227_S0008_T0012, Resource = 008_20040227_S0008_T0012
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=028_20040227_S0009_T0001, Resource = 028_20040227_S0009_T0001
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20040227_S0008_T0007, Resource = 016_20040227_S0008_T0007
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040227_S0008_T0010, Resource = 007_20040227_S0008_T0010
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 41
# Current page count: 3
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=030_20040227_S0011_T0001, Resource = 030_20040227_S0011_T0001
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=021_20040227_S0007_T0003, Resource = 021_20040227_S0007_T0003
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040227_S0008_T0005, Resource = 004_20040227_S0008_T0005
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=020_20040227_S0004_T0003, Resource = 020_20040227_S0004_T0003
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20040227_S0008_T0004, Resource = 010_20040227_S0008_T0004
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040227_S0008_T0008, Resource = 005_20040227_S0008_T0008
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20040227_S0008_T0003, Resource = 015_20040227_S0008_T0003
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20040227_S0008_T0013, Resource = 012_20040227_S0008_T0013
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20040227_S0008_T0011, Resource = 006_20040227_S0008_T0011
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20040227_S0008_T0002, Resource = 013_20040227_S0008_T0002
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20040227_S0004_T0001, Resource = 017_20040227_S0004_T0001
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20040227_S0004_T0004, Resource = 019_20040227_S0004_T0004
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_20040227_S0004_T0002, Resource = 018_20040227_S0004_T0002
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20040227_S0002, Resource = 003_20040227_S0002
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=032_20040227_S0011_T0002, Resource = 032_20040227_S0011_T0002
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=031_20040227_S0011_T0003, Resource = 031_20040227_S0011_T0003
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=024_20040227_S0006_T0001, Resource = 024_20040227_S0006_T0001
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=023_20040227_S0005_T0001, Resource = 023_20040227_S0005_T0001
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20040227_S0008_T0006, Resource = 011_20040227_S0008_T0006
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20040227_S0008_T0009, Resource = 009_20040227_S0008_T0009
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 61
# Current page count: 4
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=027_20040227_S0009_T0003, Resource = 027_20040227_S0009_T0003
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=029_20040227_S0009_T0004, Resource = 029_20040227_S0009_T0004
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=022_20040227_S0007_T0002, Resource = 022_20040227_S0007_T0002
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=026_20040227_S0009_T0002, Resource = 026_20040227_S0009_T0002
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=025_20040227_S0007_T0001, Resource = 025_20040227_S0007_T0001
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=020_20040206_S0004_T0006, Resource = 020_20040206_S0004_T0006
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20040206_S0007_T0001, Resource = 008_20040206_S0007_T0001
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20040206_S0007_T0004, Resource = 015_20040206_S0007_T0004
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20040206_S0007_T0010, Resource = 011_20040206_S0007_T0010
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=027_20040206_S0008_T0003, Resource = 027_20040206_S0008_T0003
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=026_20040206_S0008_T0004, Resource = 026_20040206_S0008_T0004
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=031_20040206_S0010_T0003, Resource = 031_20040206_S0010_T0003
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20040206_S0002, Resource = 003_20040206_S0002
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=021_20040206_S0004_T0005, Resource = 021_20040206_S0004_T0005
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20040206_S0005_T0001, Resource = 017_20040206_S0005_T0001
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=024_20040206_S0004_T0004, Resource = 024_20040206_S0004_T0004
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040206_S0007_T0006, Resource = 007_20040206_S0007_T0006
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040206_S0007_T0012, Resource = 005_20040206_S0007_T0012
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=029_20040206_S0008_T0001, Resource = 029_20040206_S0008_T0001
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20040206_S0007_T0009, Resource = 013_20040206_S0007_T0009
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 81
# Current page count: 5
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_20040206_S0004_T0003, Resource = 018_20040206_S0004_T0003
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=025_20040206_S0006_T0001, Resource = 025_20040206_S0006_T0001
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20040206_S0004_T0007, Resource = 019_20040206_S0004_T0007
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20040206_S0007_T0007, Resource = 012_20040206_S0007_T0007
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20040206_S0007_T0011, Resource = 010_20040206_S0007_T0011
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20040206_S0007_T0013, Resource = 009_20040206_S0007_T0013
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=028_20040206_S0008_T0002, Resource = 028_20040206_S0008_T0002
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040206_S0007_T0003, Resource = 004_20040206_S0007_T0003
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=030_20040206_S0010_T0002, Resource = 030_20040206_S0010_T0002
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=032_20040206_S0010_T0001, Resource = 032_20040206_S0010_T0001
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=023_20040206_S0004_T0001, Resource = 023_20040206_S0004_T0001
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=022_20040206_S0004_T0002, Resource = 022_20040206_S0004_T0002
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20040206_S0007_T0002, Resource = 014_20040206_S0007_T0002
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20040206_S0007_T0008, Resource = 016_20040206_S0007_T0008
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20040106_S0003_T0002, Resource = 011_20040106_S0003_T0002
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040106_S0005_T0008, Resource = 007_20040106_S0005_T0008
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=002_20040106_S0005_T0005, Resource = 002_20040106_S0005_T0005
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20040106_S0005_T0010, Resource = 006_20040106_S0005_T0010
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=001_20040106_S0005_T0004, Resource = 001_20040106_S0005_T0004
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20040106_S0005_T0009, Resource = 008_20040106_S0005_T0009
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 101
# Current page count: 6
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040106_S0005_T0006, Resource = 004_20040106_S0005_T0006
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20040106_S0004_T0002, Resource = 013_20040106_S0004_T0002
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20040106_S0003_T0001, Resource = 012_20040106_S0003_T0001
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040106_S0005_T0001, Resource = 005_20040106_S0005_T0001
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20040106_S0005_T0007, Resource = 009_20040106_S0005_T0007
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20040106_S0005_T0002, Resource = 003_20040106_S0005_T0002
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20040106_S0005_T0003, Resource = 010_20040106_S0005_T0003
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20040106_S0004_T0001, Resource = 014_20040106_S0004_T0001
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20040105_S0005_T0001, Resource = 010_20040105_S0005_T0001
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20040105_S0005_T0015, Resource = 014_20040105_S0005_T0015
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20040105_S0005_T0008, Resource = 007_20040105_S0005_T0008
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20040105_S0005_T0014, Resource = 005_20040105_S0005_T0014
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=029_20040105_S0006_T0001, Resource = 029_20040105_S0006_T0001
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_20040105_S0003_T0002, Resource = 018_20040105_S0003_T0002
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=000_3_20040105_S0001, Resource = 000_3_20040105_S0001
# Value Error on:000_3_20040105_S0001 , skipping
# /Users/syamil/anaconda3/envs/pivot/lib/python3.7/site-packages/ipykernel_launcher.py:140: DeprecationWarning: use driver.switch_to.window instead
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=025_20040105_S0004_T0003, Resource = 025_20040105_S0004_T0003
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20040105_S0005_T0003, Resource = 003_20040105_S0005_T0003
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20040105_S0003_T0001, Resource = 019_20040105_S0003_T0001
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=022_20040105_S0003_T0004, Resource = 022_20040105_S0003_T0004
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=020_20040105_S0003_T0003, Resource = 020_20040105_S0003_T0003
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 121
# Current page count: 7
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=026_20040105_S0004_T0002, Resource = 026_20040105_S0004_T0002
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=027_20040105_S0004_T0001, Resource = 027_20040105_S0004_T0001
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=024_20040105_S0003_T0006, Resource = 024_20040105_S0003_T0006
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20040105_S0005_T0005, Resource = 012_20040105_S0005_T0005
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20040105_S0005_T0017, Resource = 009_20040105_S0005_T0017
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20040105_S0005_T0006, Resource = 008_20040105_S0005_T0006
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=023_20040105_S0003_T0005, Resource = 023_20040105_S0003_T0005
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20040105_S0005_T0011, Resource = 006_20040105_S0005_T0011
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=002_20040105_S0005_T0009, Resource = 002_20040105_S0005_T0009
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20040105_S0005_T0012, Resource = 004_20040105_S0005_T0012
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20040105_S0005_T0004, Resource = 011_20040105_S0005_T0004
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=001_20040105_S0005_T0002, Resource = 001_20040105_S0005_T0002
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20040105_S0005_T0010, Resource = 017_20040105_S0005_T0010
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20040105_S0005_T0013, Resource = 016_20040105_S0005_T0013
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20040105_S0005_T0007, Resource = 015_20040105_S0005_T0007
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20040105_S0005_T0016, Resource = 013_20040105_S0005_T0016
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=028_20040105_S0006_T0002, Resource = 028_20040105_S0006_T0002
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=021_20040105_S0003_T0007, Resource = 021_20040105_S0003_T0007
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=023_20031111_S0003_T0007, Resource = 023_20031111_S0003_T0007
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20031111_S0005_T0001, Resource = 003_20031111_S0005_T0001
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 141
# Current page count: 8
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20031111_S0005_T0007, Resource = 010_20031111_S0005_T0007
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20031111_S0005_T0008, Resource = 011_20031111_S0005_T0008
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20031111_S0005_T0002, Resource = 005_20031111_S0005_T0002
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20031111_S0005_T0012, Resource = 009_20031111_S0005_T0012
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20031111_S0005_T0003, Resource = 007_20031111_S0005_T0003
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20031111_S0005_T0010, Resource = 012_20031111_S0005_T0010
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_20031111_S0003_T0005, Resource = 018_20031111_S0003_T0005
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20031111_S0003_T0002, Resource = 015_20031111_S0003_T0002
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20031111_S0003_T0006, Resource = 016_20031111_S0003_T0006
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20031111_S0003_T0004, Resource = 019_20031111_S0003_T0004
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20031111_S0005_T0009, Resource = 008_20031111_S0005_T0009
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=021_20031111_S0003_T0008, Resource = 021_20031111_S0003_T0008
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20031111_S0005_T0005, Resource = 014_20031111_S0005_T0005
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=022_20031111_S0003_T0001, Resource = 022_20031111_S0003_T0001
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20031111_S0005_T0004, Resource = 006_20031111_S0005_T0004
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20031111_S0005_T0011, Resource = 013_20031111_S0005_T0011
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20031111_S0003_T0009, Resource = 017_20031111_S0003_T0009
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20031111_S0005_T0006, Resource = 004_20031111_S0005_T0006
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=025_20031111_S0007_T0001, Resource = 025_20031111_S0007_T0001
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=020_20031111_S0003_T0003, Resource = 020_20031111_S0003_T0003
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 161
# Current page count: 9
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=024_20031111_S0004_T0001, Resource = 024_20031111_S0004_T0001
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=023_20031110_S0004_T0001, Resource = 023_20031110_S0004_T0001
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=029_20031110_S0005_T0004, Resource = 029_20031110_S0005_T0004
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20031110_S0006_T0008, Resource = 007_20031110_S0006_T0008
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20031110_S0006_T0003, Resource = 011_20031110_S0006_T0003
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=021_20031110_S0004_T0005, Resource = 021_20031110_S0004_T0005
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20031110_S0006_T0006, Resource = 009_20031110_S0006_T0006
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=032_20031110_S0007_T0001, Resource = 032_20031110_S0007_T0001
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=020_20031110_S0004_T0004, Resource = 020_20031110_S0004_T0004
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=027_20031110_S0005_T0003, Resource = 027_20031110_S0005_T0003
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=024_20031110_S0004_T0006, Resource = 024_20031110_S0004_T0006
# Current ID = 11
# Processing
# No Element Exists at 11, go to next
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20031110_S0006_T0013, Resource = 006_20031110_S0006_T0013
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=031_20031110_S0007_T0002, Resource = 031_20031110_S0007_T0002
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20031110_S0006_T0007, Resource = 008_20031110_S0006_T0007
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20031110_S0006_T0011, Resource = 010_20031110_S0006_T0011
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20031110_S0006_T0002, Resource = 016_20031110_S0006_T0002
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_20031110_S0006_T0009, Resource = 018_20031110_S0006_T0009
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20031110_S0006_T0010, Resource = 017_20031110_S0006_T0010
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20031110_S0006_T0001, Resource = 005_20031110_S0006_T0001
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 181
# Current page count: 10
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=033_20031110_S0007_T0003, Resource = 033_20031110_S0007_T0003
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20031110_S0004_T0003, Resource = 019_20031110_S0004_T0003
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20031110_S0002, Resource = 003_20031110_S0002
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=026_20031110_S0005_T0005, Resource = 026_20031110_S0005_T0005
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=028_20031110_S0005_T0002, Resource = 028_20031110_S0005_T0002
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=025_20031110_S0004_T0002, Resource = 025_20031110_S0004_T0002
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20031110_S0006_T0014, Resource = 012_20031110_S0006_T0014
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20031110_S0006_T0015, Resource = 015_20031110_S0006_T0015
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=022_20031110_S0004_T0007, Resource = 022_20031110_S0004_T0007
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20031110_S0006_T0004, Resource = 013_20031110_S0006_T0004
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=034_20031110_S0009_T0001, Resource = 034_20031110_S0009_T0001
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20031110_S0006_T0005, Resource = 014_20031110_S0006_T0005
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=035_20031110_S0009_T0002, Resource = 035_20031110_S0009_T0002
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=030_20031110_S0005_T0001, Resource = 030_20031110_S0005_T0001
# Current ID = 14
# Processing
# No Element Exists at 14, go to next
# Current ID = 15
# Processing
# No Element Exists at 15, go to next
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20031016_S0004_T0001, Resource = 017_20031016_S0004_T0001
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_10031016_S0004_T0002, Resource = 018_10031016_S0004_T0002
# Index of JSON not found,skipping
# /Users/syamil/anaconda3/envs/pivot/lib/python3.7/site-packages/ipykernel_launcher.py:105: DeprecationWarning: use driver.switch_to.window instead
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20031016_S0006_T0002, Resource = 015_20031016_S0006_T0002
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20031016_S0006_T0009, Resource = 014_20031016_S0006_T0009
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 201
# Current page count: 11
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20031016_S0006_T0012, Resource = 016_20031016_S0006_T0012
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20031016_S0006_T0006, Resource = 012_20031016_S0006_T0006
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20031016_S0006_T0014, Resource = 013_20031016_S0006_T0014
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20031016_S0006_T0010, Resource = 011_20031016_S0006_T0010
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_20031016_S0003_T0006, Resource = 018_20031016_S0003_T0006
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=043_20031016_S0009_T0003, Resource = 043_20031016_S0009_T0003
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=039_20031016_S0007_T0001, Resource = 039_20031016_S0007_T0001
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=037_20031016_S0007_T0002, Resource = 037_20031016_S0007_T0002
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=036_20031016_S0007_T0004, Resource = 036_20031016_S0007_T0004
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=044_20031016_S0009_T0006, Resource = 044_20031016_S0009_T0006
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=042_20031016_S0009_T0004, Resource = 042_20031016_S0009_T0004
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=038_20031016_S0007_T0003, Resource = 038_20031016_S0007_T0003
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=041_20031016_S0009_T0002, Resource = 041_20031016_S0009_T0002
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=040_20031016_S0009_T0005, Resource = 040_20031016_S0009_T0005
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20031016_S0006_T0001, Resource = 006_20031016_S0006_T0001
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20031016_S0006_T0008, Resource = 008_20031016_S0006_T0008
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20031016_S0006_T0013, Resource = 004_20031016_S0006_T0013
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20031016_S0006_T0004, Resource = 010_20031016_S0006_T0004
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20031016_S0006_T0011, Resource = 005_20031016_S0006_T0011
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20031016_S0006_T0003, Resource = 009_20031016_S0006_T0003
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 221
# Current page count: 12
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20031016_S0006_T0007, Resource = 007_20031016_S0006_T0007
# Current ID = 1
# Processing
# No Element Exists at 1, go to next
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_10031016_S0006_T0005, Resource = 011_10031016_S0006_T0005
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=021_20031016_S0003_T0007, Resource = 021_20031016_S0003_T0007
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=023_20031016_S0003_T0012, Resource = 023_20031016_S0003_T0012
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20031016_S0003_T0010, Resource = 019_20031016_S0003_T0010
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=025_20031016_S0003_T0011, Resource = 025_20031016_S0003_T0011
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=022_20031016_S0003_T0003, Resource = 022_20031016_S0003_T0003
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=026_20031016_S0003_T0005, Resource = 026_20031016_S0003_T0005
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=024_20031016_S0003_T0015, Resource = 024_20031016_S0003_T0015
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=027_20031016_S0003_T0014, Resource = 027_20031016_S0003_T0014
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=020_20031016_S0003_T0002, Resource = 020_20031016_S0003_T0002
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=035_20031016_S0005_T0004, Resource = 035_20031016_S0005_T0004
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=030_20031016_S0003_T0008, Resource = 030_20031016_S0003_T0008
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=032_20031016_S0003_T0004, Resource = 032_20031016_S0003_T0004
# JSON Error on:032_20031016_S0003_T0004 , retrying
# /Users/syamil/anaconda3/envs/pivot/lib/python3.7/site-packages/ipykernel_launcher.py:123: DeprecationWarning: use driver.switch_to.window instead
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=032_20031016_S0003_T0004, Resource = 032_20031016_S0003_T0004
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=032_10031016_S0003_T0009, Resource = 032_10031016_S0003_T0009
# Index of JSON not found,skipping
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=029_20031016_S0003_T0013, Resource = 029_20031016_S0003_T0013
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=028_20031016_S0003_T0001, Resource = 028_20031016_S0003_T0001
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=034_20031016_S0005_T0001, Resource = 034_20031016_S0005_T0001
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=031_20031016_S0005_T0003, Resource = 031_20031016_S0005_T0003
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 241
# Current page count: 13
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=033_20031016_S0005_T0002, Resource = 033_20031016_S0005_T0002
# Current ID = 1
# Processing
# No Element Exists at 1, go to next
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20030902_S0004_T0007, Resource = 010_20030902_S0004_T0007
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20030902_S0004_T0008, Resource = 006_20030902_S0004_T0008
# Index of JSON not found,skipping
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20030902_S0003_T0006, Resource = 003_20030902_S0003_T0006
# Index of JSON not found,skipping
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20030902_S0002_T0002, Resource = 009_20030902_S0002_T0002
# Index of JSON not found,skipping
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20030902_S0002_T0003, Resource = 008_20030902_S0002_T0003
# Index of JSON not found,skipping
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20030902_S0002_T0005, Resource = 005_20030902_S0002_T0005
# Index of JSON not found,skipping
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20030902_S0002_T0004, Resource = 007_20030902_S0002_T0004
# Index of JSON not found,skipping
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20030902_S0004_T0009, Resource = 004_20030902_S0004_T0009
# Index of JSON not found,skipping
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20030901_S0002_T0005, Resource = 004_20030901_S0002_T0005
# Index of JSON not found,skipping
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20030901_S0002_T0004, Resource = 005_20030901_S0002_T0004
# Index of JSON not found,skipping
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20030901_S0003_T0006, Resource = 003_20030901_S0003_T0006
# Index of JSON not found,skipping
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20030901_S0002_T0002, Resource = 006_20030901_S0002_T0002
# Index of JSON not found,skipping
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20030901_S0002_T0003, Resource = 007_20030901_S0002_T0003
# Index of JSON not found,skipping
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20030829_S0004_T0013, Resource = 003_20030829_S0004_T0013
# Index of JSON not found,skipping
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20030829_S0004_T0011, Resource = 005_20030829_S0004_T0011
# Index of JSON not found,skipping
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20030829_S0002_T0002, Resource = 008_20030829_S0002_T0002
# Index of JSON not found,skipping
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20030829_S0003_T0004, Resource = 014_20030829_S0003_T0004
# Index of JSON not found,skipping
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20030829_S0003_T0007, Resource = 009_20030829_S0003_T0007
# Index of JSON not found,skipping
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 261
# Current page count: 14
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20030829_S0003_T0006, Resource = 011_20030829_S0003_T0006
# Index of JSON not found,skipping
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20030829_S0004_T0009, Resource = 007_20030829_S0004_T0009
# Index of JSON not found,skipping
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20030829_S0004_T0010, Resource = 004_20030829_S0004_T0010
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20030829_S0004_T0012, Resource = 006_20030829_S0004_T0012
# Index of JSON not found,skipping
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20030829_S0003_T0008, Resource = 010_20030829_S0003_T0008
# Index of JSON not found,skipping
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20030829_S0003_T0003, Resource = 013_20030829_S0003_T0003
# Index of JSON not found,skipping
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20030829_S0003_T0005, Resource = 012_20030829_S0003_T0005
# Index of JSON not found,skipping
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20030828_S0005_T0014, Resource = 004_20030828_S0005_T0014
# Index of JSON not found,skipping
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20030828_S0005_T0016, Resource = 010_20030828_S0005_T0016
# Index of JSON not found,skipping
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20030828_S0005_T0011, Resource = 012_20030828_S0005_T0011
# Index of JSON not found,skipping
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20030828_S0002_T0002, Resource = 015_20030828_S0002_T0002
# Index of JSON not found,skipping
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20030828_S0004_T0005, Resource = 019_20030828_S0004_T0005
# Index of JSON not found,skipping
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20030828_S0002_T0003, Resource = 014_20030828_S0002_T0003
# Index of JSON not found,skipping
# Current ID = 13
# Processing
# No Element Exists at 13, go to next
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20030828_S0004_T0008, Resource = 017_20030828_S0004_T0008
# Index of JSON not found,skipping
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20030828_S0003_T0004, Resource = 016_20030828_S0003_T0004
# Index of JSON not found,skipping
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20030828_S0005_T0009, Resource = 007_20030828_S0005_T0009
# Index of JSON not found,skipping
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20030828_S0005_T0010, Resource = 005_20030828_S0005_T0010
# Index of JSON not found,skipping
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20030828_S0005_T0015, Resource = 006_20030828_S0005_T0015
# Index of JSON not found,skipping
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20030828_S0005_T0018, Resource = 011_20030828_S0005_T0018
# Index of JSON not found,skipping
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 281
# Current page count: 15
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20030828_S0005_T0013, Resource = 003_20030828_S0005_T0013
# Index of JSON not found,skipping
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20030828_S0004_T0007, Resource = 013_20030828_S0004_T0007
# Index of JSON not found,skipping
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20030828_S0005_T0012, Resource = 008_20030828_S0005_T0012
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20030828_S0005_T0017, Resource = 009_20030828_S0005_T0017
# Index of JSON not found,skipping
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20030815_S0002_T0002, Resource = 011_20030815_S0002_T0002
# Index of JSON not found,skipping
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20030815_S0004_T0006, Resource = 005_20030815_S0004_T0006
# Index of JSON not found,skipping
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20030815_S0004_T0011, Resource = 010_20030815_S0004_T0011
# Index of JSON not found,skipping
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20030815_S0004_T0008, Resource = 006_20030815_S0004_T0008
# Index of JSON not found,skipping
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20030815_S0004_T0004, Resource = 009_20030815_S0004_T0004
# Index of JSON not found,skipping
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20030815_S0004_T0007, Resource = 003_20030815_S0004_T0007
# Index of JSON not found,skipping
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20030815_S0004_T0010, Resource = 007_20030815_S0004_T0010
# Index of JSON not found,skipping
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20030815_S0004_T0005, Resource = 008_20030815_S0004_T0005
# Index of JSON not found,skipping
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20030815_S0004_T0009, Resource = 004_20030815_S0004_T0009
# Index of JSON not found,skipping
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20030815_S0003_T0003, Resource = 012_20030815_S0003_T0003
# Index of JSON not found,skipping
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20030814_S0004_T0010, Resource = 013_20030814_S0004_T0010
# Index of JSON not found,skipping
# Current ID = 15
# Processing
# ...
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20021031_S0002_T0004, Resource = 019_20021031_S0002_T0004
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=033_20021031_S0006_T0026, Resource = 033_20021031_S0006_T0026
# Index of JSON not found,skipping
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20021031_S0007_T0035, Resource = 005_20021031_S0007_T0035
# Index of JSON not found,skipping
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=034_20021031_S0006_T0031, Resource = 034_20021031_S0006_T0031
# Index of JSON not found,skipping
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=037_20021031_S0006_T0025, Resource = 037_20021031_S0006_T0025
# Index of JSON not found,skipping
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=031_20021031_S0006_T0032, Resource = 031_20021031_S0006_T0032
# Index of JSON not found,skipping
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=039_20021031_S0009_T0040, Resource = 039_20021031_S0009_T0040
# Index of JSON not found,skipping
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20021031_S0002_T0013, Resource = 013_20021031_S0002_T0013
# Index of JSON not found,skipping
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20021031_S0002_T0010, Resource = 011_20021031_S0002_T0010
# Index of JSON not found,skipping
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=036_20021031_S0006_T0027, Resource = 036_20021031_S0006_T0027
# Index of JSON not found,skipping
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20021031_S0003_T0018, Resource = 004_20021031_S0003_T0018
# Index of JSON not found,skipping
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20021031_S0002_T0016, Resource = 014_20021031_S0002_T0016
# Index of JSON not found,skipping
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20021031_S0002_T0015, Resource = 010_20021031_S0002_T0015
# Index of JSON not found,skipping
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=020_20021031_S0004_T0019, Resource = 020_20021031_S0004_T0019
# Index of JSON not found,skipping
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=027_20021031_S0006_T0022, Resource = 027_20021031_S0006_T0022
# Index of JSON not found,skipping
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20021031_S0002_T0012, Resource = 017_20021031_S0002_T0012
# Index of JSON not found,skipping
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=041_20021031_S0009_T0039, Resource = 041_20021031_S0009_T0039
# Index of JSON not found,skipping
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=029_20021031_S0006_T0023, Resource = 029_20021031_S0006_T0023
# Index of JSON not found,skipping
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 581
# Current page count: 31
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=025_20021031_S0006_T0030, Resource = 025_20021031_S0006_T0030
# Index of JSON not found,skipping
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=030_20021031_S0006_T0033, Resource = 030_20021031_S0006_T0033
# Index of JSON not found,skipping
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20021031_S0002_T0006, Resource = 008_20021031_S0002_T0006
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=043_20021031_S0002_T0002, Resource = 043_20021031_S0002_T0002
# Index of JSON not found,skipping
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=023_20021031_S0002_T0009, Resource = 023_20021031_S0002_T0009
# Index of JSON not found,skipping
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=022_20021031_S0002_T0014, Resource = 022_20021031_S0002_T0014
# Index of JSON not found,skipping
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20021031_S0007_T0036, Resource = 006_20021031_S0007_T0036
# Index of JSON not found,skipping
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20021031_S0002_T0005, Resource = 016_20021031_S0002_T0005
# Index of JSON not found,skipping
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=028_20021031_S0006_T0021, Resource = 028_20021031_S0006_T0021
# Index of JSON not found,skipping
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=042_20021031_S0009_T0041, Resource = 042_20021031_S0009_T0041
# Index of JSON not found,skipping
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=026_20021031_S0006_T0028, Resource = 026_20021031_S0006_T0028
# Index of JSON not found,skipping
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=040_20021031_S0009_T0043, Resource = 040_20021031_S0009_T0043
# Index of JSON not found,skipping
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=038_20021031_S0009_T0042, Resource = 038_20021031_S0009_T0042
# Index of JSON not found,skipping
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=021_20021031_S0002_T0007, Resource = 021_20021031_S0002_T0007
# Index of JSON not found,skipping
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20021031_S0002_T0011, Resource = 015_20021031_S0002_T0011
# Index of JSON not found,skipping
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20021031_S0007_T0034, Resource = 007_20021031_S0007_T0034
# Index of JSON not found,skipping
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=032_20021031_S0006_T0029, Resource = 032_20021031_S0006_T0029
# Index of JSON not found,skipping
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=035_20021031_S0006_T0024, Resource = 035_20021031_S0006_T0024
# Index of JSON not found,skipping
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20021031_S0002_T0017, Resource = 012_20021031_S0002_T0017
# Index of JSON not found,skipping
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20021031_S0002_T0008, Resource = 009_20021031_S0002_T0008
# Index of JSON not found,skipping
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 601
# Current page count: 32
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=024_20021031_S0005_T0020, Resource = 024_20021031_S0005_T0020
# Index of JSON not found,skipping
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20021031_S0007_T0037, Resource = 003_20021031_S0007_T0037
# Index of JSON not found,skipping
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_20021031_S0002_T0003, Resource = 018_20021031_S0002_T0003
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20021002_S0002_T0003, Resource = 004_20021002_S0002_T0003
# Index of JSON not found,skipping
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20021002_S0002_T0004, Resource = 006_20021002_S0002_T0004
# Index of JSON not found,skipping
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20021002_S0003_T0005, Resource = 003_20021002_S0003_T0005
# Index of JSON not found,skipping
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20021002_S0002_T0002, Resource = 005_20021002_S0002_T0002
# Index of JSON not found,skipping
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=023_20021001_S0004_T0015, Resource = 023_20021001_S0004_T0015
# Index of JSON not found,skipping
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=021_20021001_S0003_T0008, Resource = 021_20021001_S0003_T0008
# Index of JSON not found,skipping
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20021001_S0003_T0009, Resource = 013_20021001_S0003_T0009
# Index of JSON not found,skipping
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20021001_S0003_T0003, Resource = 016_20021001_S0003_T0003
# Index of JSON not found,skipping
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20021001_S0003_T0005, Resource = 014_20021001_S0003_T0005
# Index of JSON not found,skipping
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=019_20021001_S0003_T0006, Resource = 019_20021001_S0003_T0006
# Index of JSON not found,skipping
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=018_20021001_S0003_T0004, Resource = 018_20021001_S0003_T0004
# Index of JSON not found,skipping
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20021001_S0003_T0010, Resource = 015_20021001_S0003_T0010
# Index of JSON not found,skipping
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=024_20021001_S0004_T0014, Resource = 024_20021001_S0004_T0014
# Index of JSON not found,skipping
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20021001_S0006_T0021, Resource = 006_20021001_S0006_T0021
# Index of JSON not found,skipping
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=026_20021001_S0005_T0016, Resource = 026_20021001_S0005_T0016
# Index of JSON not found,skipping
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20021001_S0006_T0019, Resource = 011_20021001_S0006_T0019
# Index of JSON not found,skipping
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20021001_S0006_T0022, Resource = 007_20021001_S0006_T0022
# Index of JSON not found,skipping
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 621
# Current page count: 33
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20021001_S0006_T0026, Resource = 009_20021001_S0006_T0026
# Index of JSON not found,skipping
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20021001_S0006_T0023, Resource = 005_20021001_S0006_T0023
# Index of JSON not found,skipping
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=028_20021001_S0008_T0028, Resource = 028_20021001_S0008_T0028
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=020_20021001_S0003_T0012, Resource = 020_20021001_S0003_T0012
# Index of JSON not found,skipping
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20021001_S0006_T0025, Resource = 008_20021001_S0006_T0025
# Index of JSON not found,skipping
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20021001_S0006_T0018, Resource = 012_20021001_S0006_T0018
# Index of JSON not found,skipping
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=022_20021001_S0003_T0007, Resource = 022_20021001_S0003_T0007
# Index of JSON not found,skipping
# Current ID = 7
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20021001_S0006_T0024, Resource = 004_20021001_S0006_T0024
# Index of JSON not found,skipping
# Current ID = 8
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20021001_S0006_T0020, Resource = 010_20021001_S0006_T0020
# Index of JSON not found,skipping
# Current ID = 9
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=027_20021001_S0005_T0017, Resource = 027_20021001_S0005_T0017
# Index of JSON not found,skipping
# Current ID = 10
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=025_20021001_S0004_T0013, Resource = 025_20021001_S0004_T0013
# Index of JSON not found,skipping
# Current ID = 11
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=017_20021001_S0003_T0011, Resource = 017_20021001_S0003_T0011
# Index of JSON not found,skipping
# Current ID = 12
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20021001_S0001_T0001, Resource = 003_20021001_S0001_T0001
# Index of JSON not found,skipping
# Current ID = 13
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=012_20020828_S0004_T0010, Resource = 012_20020828_S0004_T0010
# Index of JSON not found,skipping
# Current ID = 14
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=007_20020828_S0004_T0007, Resource = 007_20020828_S0004_T0007
# Index of JSON not found,skipping
# Current ID = 15
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=005_20020828_S0004_T0008, Resource = 005_20020828_S0004_T0008
# Index of JSON not found,skipping
# Current ID = 16
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=008_20020828_S0004_T0015, Resource = 008_20020828_S0004_T0015
# Index of JSON not found,skipping
# Current ID = 17
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=013_20020828_S0004_T0009, Resource = 013_20020828_S0004_T0009
# Index of JSON not found,skipping
# Current ID = 18
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=009_20020828_S0004_T0006, Resource = 009_20020828_S0004_T0006
# Index of JSON not found,skipping
# Current ID = 19
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=015_20020828_S0002_T0002, Resource = 015_20020828_S0002_T0002
# Index of JSON not found,skipping
#
#  ////////////////// NEW PAGE ////////////////////////
#
# Number of results so far : 641
# Current page count: 34
# Current ID = 0
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=016_20020828_S0003_T0003, Resource = 016_20020828_S0003_T0003
# Index of JSON not found,skipping
# Current ID = 1
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=014_20020828_S0003_T0004, Resource = 014_20020828_S0003_T0004
# Index of JSON not found,skipping
# Current ID = 2
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=006_20020828_S0004_T0005, Resource = 006_20020828_S0004_T0005
# Index of JSON not found,skipping
# Current ID = 3
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=004_20020828_S0004_T0011, Resource = 004_20020828_S0004_T0011
# Index of JSON not found,skipping
# Current ID = 4
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=003_20020828_S0004_T0012, Resource = 003_20020828_S0004_T0012
# Index of JSON not found,skipping
# Current ID = 5
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=010_20020828_S0004_T0013, Resource = 010_20020828_S0004_T0013
# Index of JSON not found,skipping
# Current ID = 6
# Processing
# Current URL : https://sprs.parl.gov.sg/search/topic?reportid=011_20020828_S0004_T0014, Resource = 011_20020828_S0004_T0014
# Index of JSON not found,skipping
# Total of 648 links processed
# KeyboardInterrupt
