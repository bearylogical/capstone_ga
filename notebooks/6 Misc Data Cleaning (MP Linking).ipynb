# %% [markdown]
# ## Linking of Entities to DB

# %%
from bs4 import BeautifulSoup
import re

from tqdm import tqdm
import numpy as np
import pandas as pd

import json

# %% [markdown]
# ## Get Data from Mongo DB

# %%
import os
import yaml
import pymongo

with open("config.yaml", "r") as ymlfile:
    settings = yaml.safe_load(ymlfile)


isRemote = False


try:
    if (isRemote):
        client = pymongo.MongoClient(host = settings['mongo-remote']['host'],
                                     port = settings['mongo-remote']['port'],
                                     username = settings['mongo-remote']['user'],
                                     password = settings['mongo-remote']['pw'],
                                     authMechanism= settings['mongo-remote']['authMechanism'])
        client.server_info()  # force connection on a request as the
        # connect=True parameter of MongoClient seems
        # to be useless here
    else:
        client = pymongo.MongoClient("mongodb://localhost:27017/")
        client.server_info()  # force connection on a request as the
    # connect=True parameter of MongoClient seems
    # to be useless here
except pymongo.errors.ServerSelectionTimeoutError as err:
    # do whatever you need
    print(err)

# %% [markdown]
# ## Check DB Contents

# %%
db = client["parliament"]
articles = db["articles"]

# %%
mongo_df = pd.DataFrame.from_records(articles.find())
mongo_df.head()
# Out:
#                         _id  \
# 0  5d27eca6172d9aa762d4802f
# 1  5d27eca6172d9aa762d48030
# 2  5d27eca6172d9aa762d48031
# 3  5d27eca6172d9aa762d48032
# 4  5d27eca6172d9aa762d48033
#
#                                         article_text  \
# 0  <p>[(proc text) Debate resumed. (proc text)]</...
# 1  <p class="ql-align-justify">4 <strong>Mr Vikra...
# 2  <p class="ql-align-justify">8 <strong>Assoc Pr...
# 3  <p>5 <strong>Ms Irene Quay Siew Ching</strong>...
# 4  <p class="ql-align-justify">2 <strong>Mr Lim B...
#
#                                               chunks  \
# 0  {"0": {"entity": "NA", "content": "[(proc text...
# 1  {"0": {"entity": "NA", "content": "Mr Vikram N...
# 2  {"0": {"entity": "NA", "content": "Assoc Prof ...
# 3  {"0": {"entity": "NA", "content": "Ms Irene Qu...
# 4  {"0": {"entity": "NA", "content": "Mr Lim Biow...
#
#                                         cleaned_join     dominant_topic  \
# 0  [(proc text) Debate resumed. (proc text)]<br/>...            Society
# 1  Mr Vikram Nair asked the Minister for Foreign ...            Society
# 2  Assoc Prof Walter Theseira asked the Minister ...  Internal Security
# 3  Ms Irene Quay Siew Ching asked the Minister fo...        Environment
# 4  Mr Lim Biow Chuan asked the Deputy Prime Minis...         Employment
#
#                                           html_clean  parliament_num  \
# 0  [[(proc text) Debate resumed. (proc text)], Mr...              13
# 1  [Mr Vikram Nair asked the Minister for Foreign...              13
# 2  [Assoc Prof Walter Theseira asked the Minister...              13
# 3  [Ms Irene Quay Siew Ching asked the Minister f...              13
# 4  [Mr Lim Biow Chuan asked the Deputy Prime Mini...              13
#
#                                         parsed_convo  \
# 0  [{'content': '[(proc text) Debate resumed. (pr...
# 1  [{'content': 'Mr Vikram Nair asked the Ministe...
# 2  [{'content': 'Assoc Prof Walter Theseira asked...
# 3  [{'content': 'Ms Irene Quay Siew Ching asked t...
# 4  [{'content': 'Mr Lim Biow Chuan asked the Depu...
#
#                                     persons_involved  session_num  \
# 0  [Prof Lim Sun Sun, Miss Cheng Li Hui, An hon M...            2
# 1  [Mr Speaker, Assoc Prof Walter Theseira, Mr Vi...            2
# 2  [Ms Anthea Ong, Assoc Prof Walter Theseira, Ms...            2
# 3  [Ms Irene Quay Siew Ching, Dr Lam Pin Min, The...            2
# 4  [The Second Minister for Finance, Mr Lim Biow ...            2
#
#            session_type sitting_date  sitting_num  \
# 0  SECOND READING BILLS   2019-05-08          105
# 1          ORAL ANSWERS   2019-05-08          105
# 2          ORAL ANSWERS   2019-05-08          105
# 3          ORAL ANSWERS   2019-05-08          105
# 4          ORAL ANSWERS   2019-05-08          105
#
#                                              src_url  \
# 0  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 1  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 2  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 3  https://sprs.parl.gov.sg/search/sprs3topic?rep...
# 4  https://sprs.parl.gov.sg/search/sprs3topic?rep...
#
#                                                title  volume_num
# 0  PROTECTION FROM ONLINE FALSEHOODS AND MANIPULA...          94
# 1  STATE OF BILATERAL RELATIONS WITH MALAYSIA FOL...          94
# 2  COMPANIES WITH MEASURES TO DEAL WITH WORKPLACE...          94
# 3  REVIEW OF DRUG TESTING STANDARDS IN SINGAPORE ...          94
# 4  LIVING IN PRIVATE PROPERTIES BUT WITH NO DECLA...          94

# %% [markdown]
# ## Get Entity-Content Dataframe
#
# Here, we create a template dataframe for us to go through each document. Then, as we iterate through each document, an entity-conent mapping is formed.

# %%
entities_content = pd.DataFrame(columns=['entity','content','docid'])

# %%
import json

for row in tqdm(mongo_df.itertuples()):
    chunks = json.loads(row.chunks)
    for content in chunks.values():
        if content['entity'] != 'NA':
            entities_content = entities_content.append({
            'entity' :  content['entity'],
            'content' : content['content'],
            'docid' : row._1
        }, ignore_index = True)
# Out:
# 9531it [02:44, 58.10it/s]

# %%
entities_content.head()
# Out:
#                                               entity  \
# 0          [(proc text) Debate resumed. (proc text)]
# 1                                  Mr Deputy Speaker
# 2                          Mr Png Eng Huat (Hougang)
# 3                                  Mr Deputy Speaker
# 4  The Minister for Communications and Informatio...
#
#                                              content                     docid
# 0          [(proc text) Debate resumed. (proc text)]  5d27eca6172d9aa762d4802f
# 1         Mr Deputy Speaker: Mr Png Eng Huat.6.57 pm  5d27eca6172d9aa762d4802f
# 2  Mr Png Eng Huat (Hougang): Sir, if this Bill i...  5d27eca6172d9aa762d4802f
# 3        Mr Deputy Speaker: Minister Iswaran.7.08 pm  5d27eca6172d9aa762d4802f
# 4  The Minister for Communications and Informatio...  5d27eca6172d9aa762d4802f

# %% [markdown]
# We then map entity and content to party and designation using the `fuzzywuzzy` library.

# %%
consolidated_names = pd.read_csv('consolidated.csv')
consolidated_names.drop(columns='Unnamed: 0',inplace=True)

# %%
consolidated_names.head()
# Out:
#                 clean_designation constituency  \
# 0  Nominated Member of Parliament          NaN
# 1  Nominated Member of Parliament          NaN
# 2  Nominated Member of Parliament          NaN
# 3  Nominated Member of Parliament          NaN
# 4  Nominated Member of Parliament          NaN
#
#                       designation                   name  \
# 0  Nominated Member of Parliament           Maurice Choo
# 1  Nominated Member of Parliament        Leong Chee Whye
# 2  Nominated Member of Parliament          Chia Shi Teck
# 3  Nominated Member of Parliament  Robert Chua Teck Chew
# 4  Nominated Member of Parliament         Kanwaljit Soin
#
#                             party
# 0  Nominated Member of Parliament
# 1  Nominated Member of Parliament
# 2  Nominated Member of Parliament
# 3  Nominated Member of Parliament
# 4  Nominated Member of Parliament

# %%
from fuzzywuzzy import process, fuzz

# %%
def return_names(entity):
    if entity != '':
        try:
            matched_idx = process.extractOne(entity,consolidated_names.name,scorer=fuzz.token_set_ratio, score_cutoff=80) [2]
            name = consolidated_names.iloc[matched_idx]['name']
        except TypeError:
            name = 'NA'
            pass
        return name
    else:
        pass

# %%
# %time entities_content['lookup_name'] = entities_content.entity.map(return_names)

# %%
entities_content[entities_content['lookup_name'] != "NA"]
entities_content = entities_content[entities_content['lookup_name'] != "NA"]

# %%
entities_content['words_len'] = entities_content.content.map(lambda x : len(x.split()))
entities_content['speech_mins'] = entities_content.content.map(lambda x : round(len(x.split())/265,2))

# %% [markdown]
# A reference table is created that contains all relevant metadata associated with the content of the speech.

# %%
## merge with master dataframe for additional meta deta
reference_table = entities_content.merge(mongo_df,how="inner",right_on="_id",left_on="docid")

# %%
filter_columns= ['entity','content','docid','lookup_name','words_len','speech_mins',
                 'dominant_topic','parliament_num','session_num','sitting_date','sitting_num']

reference_table = reference_table[filter_columns]

# %%
reference_table['year'] = reference_table.sitting_date.map(lambda x : x.year)

# %% [markdown]
# ## Trend of speech time against years

# %%
reference_table.head()
# Out:
#                                               entity  \
# 0                          Mr Png Eng Huat (Hougang)
# 1  The Minister for Communications and Informatio...
# 2                     Dr Chia Shi-Lu (Tanjong Pagar)
# 3                       Mr Darryl David (Ang Mo Kio)
# 4                   Mr Louis Ng Kok Kwang (Nee Soon)
#
#                                              content  \
# 0  Mr Png Eng Huat (Hougang): Sir, if this Bill i...
# 1  The Minister for Communications and Informatio...
# 2  Dr Chia Shi-Lu (Tanjong Pagar): Mr Deputy Spea...
# 3  Mr Darryl David (Ang Mo Kio): Mr Deputy Speake...
# 4  Mr Louis Ng Kok Kwang (Nee Soon): Sir, online ...
#
#                       docid         lookup_name  words_len  speech_mins  \
# 0  5d27eca6172d9aa762d4802f        PNG ENG HUAT       1802         6.80
# 1  5d27eca6172d9aa762d4802f           S ISWARAN       3903        14.73
# 2  5d27eca6172d9aa762d4802f         CHIA SHI-LU       1771         6.68
# 3  5d27eca6172d9aa762d4802f        DARRYL DAVID        802         3.03
# 4  5d27eca6172d9aa762d4802f  LOUIS NG KOK KWANG        704         2.66
#
#   dominant_topic  parliament_num  session_num sitting_date  sitting_num  year
# 0        Society              13            2   2019-05-08          105  2019
# 1        Society              13            2   2019-05-08          105  2019
# 2        Society              13            2   2019-05-08          105  2019
# 3        Society              13            2   2019-05-08          105  2019
# 4        Society              13            2   2019-05-08          105  2019

# %%
reference_table.groupby(by="year")['speech_mins'].sum()
# Out:
# year
# 2009    4697.23
# 2010    4517.98
# 2011    4443.71
# 2012    7008.87
# 2013    6421.03
# 2014    7157.26
# 2015    5125.50
# 2016    7931.82
# 2017    8085.80
# 2018    8920.30
# 2019    5693.41
# Name: speech_mins, dtype: float64

# %%
reference_table = reference_table.merge(consolidated_names,how="inner",left_on="lookup_name",right_on="name")

# %%
reference_table.head()
# Out:
#                       entity  \
# 0  Mr Png Eng Huat (Hougang)
# 1  Mr Png Eng Huat (Hougang)
# 2            Mr Png Eng Huat
# 3            Mr Png Eng Huat
# 4            Mr Png Eng Huat
#
#                                              content  \
# 0  Mr Png Eng Huat (Hougang): Sir, if this Bill i...
# 1  Mr Png Eng Huat (Hougang): Sir, if this Bill i...
# 2  Mr Png Eng Huat: Thank you, Deputy Speaker. Ju...
# 3  Mr Png Eng Huat: Thank you, Deputy Speaker. Ju...
# 4  Mr Png Eng Huat: — but POFMA is supposed to ad...
#
#                       docid   lookup_name  words_len  speech_mins  \
# 0  5d27eca6172d9aa762d4802f  PNG ENG HUAT       1802         6.80
# 1  5d27eca6172d9aa762d4802f  PNG ENG HUAT       1802         6.80
# 2  5d27eca6172d9aa762d4802f  PNG ENG HUAT         65         0.25
# 3  5d27eca6172d9aa762d4802f  PNG ENG HUAT         65         0.25
# 4  5d27eca6172d9aa762d4802f  PNG ENG HUAT         14         0.05
#
#   dominant_topic  parliament_num  session_num sitting_date  sitting_num  year  \
# 0        Society              13            2   2019-05-08          105  2019
# 1        Society              13            2   2019-05-08          105  2019
# 2        Society              13            2   2019-05-08          105  2019
# 3        Society              13            2   2019-05-08          105  2019
# 4        Society              13            2   2019-05-08          105  2019
#
#       clean_designation constituency           designation          name  \
# 0  Member of Parliament      Hougang  Member of Parliament  PNG ENG HUAT
# 1                   NaN          NaN                   NaN  PNG ENG HUAT
# 2  Member of Parliament      Hougang  Member of Parliament  PNG ENG HUAT
# 3                   NaN          NaN                   NaN  PNG ENG HUAT
# 4  Member of Parliament      Hougang  Member of Parliament  PNG ENG HUAT
#
#             party
# 0  Workers' Party
# 1  Workers' Party
# 2  Workers' Party
# 3  Workers' Party
# 4  Workers' Party

# %%
reference_table.party.value_counts()
# Out:
# People's Action Party             35468
# Workers' Party                     3256
# Nominated Member of Parliament     2537
# Singapore People's Party             35
# Presidential Office                   3
# Barisan Sosialis                      1
# Name: party, dtype: int64

# %%
reference_table[reference_table['party']=='Pertubuhan Kebangsaan Melayu Singapura']
# Out:
# Empty DataFrame
# Columns: [entity, content, docid, lookup_name, words_len, speech_mins, dominant_topic, parliament_num, session_num, sitting_date, sitting_num, year, clean_designation, constituency, designation, name, party]
# Index: []

# %%
reference_table[reference_table['party']=='Singapore People\'s Party'].head(6)
# Out:
#                                  entity  \
# 40062  Mr Chiam See Tong (Potong Pasir)
# 40063                 Mr Chiam See Tong
# 40064  Mr Chiam See Tong (Potong Pasir)
# 40065  Mr Chiam See Tong (Potong Pasir)
# 40066  Mr Chiam See Tong (Potong Pasir)
# 40067                 Mr Chiam See Tong
#
#                                                  content  \
# 40062   Thank you for giving me the opportunity to sp...
# 40063   Children and adults with special needs deserv...
# 40064   In November 2009, it was reported that IRAS d...
# 40065   Sir, at the moment, about 40% of places in on...
# 40066   Thank you, Sir, for allowing me to join in th...
# 40067   Sir, Singapore's sovereign wealth fund compan...
#
#                           docid     lookup_name  words_len  speech_mins  \
# 40062  5d27eca6172d9aa762d49929  CHIAM SEE TONG        193         0.73
# 40063  5d27eca6172d9aa762d49973  CHIAM SEE TONG        104         0.39
# 40064  5d27eca6172d9aa762d49adf  CHIAM SEE TONG        117         0.44
# 40065  5d27eca6172d9aa762d4a033  CHIAM SEE TONG        115         0.43
# 40066  5d27eca6172d9aa762d4a0da  CHIAM SEE TONG        177         0.67
# 40067  5d27eca6172d9aa762d4a0e6  CHIAM SEE TONG        106         0.40
#
#       dominant_topic  parliament_num  session_num sitting_date  sitting_num  \
# 40062            Law              11            2   2011-03-09           25
# 40063     Healthcare              11            2   2011-03-04           22
# 40064       Business              11            2   2010-03-09           22
# 40065      Education              11            1   2009-02-10           14
# 40066       Business              11            2   2011-03-10           26
# 40067     Employment              11            2   2011-03-09           25
#
#        year clean_designation constituency designation            name  \
# 40062  2011               NaN          NaN         NaN  CHIAM SEE TONG
# 40063  2011               NaN          NaN         NaN  CHIAM SEE TONG
# 40064  2010               NaN          NaN         NaN  CHIAM SEE TONG
# 40065  2009               NaN          NaN         NaN  CHIAM SEE TONG
# 40066  2011               NaN          NaN         NaN  CHIAM SEE TONG
# 40067  2011               NaN          NaN         NaN  CHIAM SEE TONG
#
#                           party
# 40062  Singapore People's Party
# 40063  Singapore People's Party
# 40064  Singapore People's Party
# 40065  Singapore People's Party
# 40066  Singapore People's Party
# 40067  Singapore People's Party

# %%
reference_table['lookup_name'] = reference_table.lookup_name.map(lambda x : 'Faizah binte Haji Ahmad Jamal'if x == 'JAMAL BIN IDRIS'else x)
reference_table['name'] = reference_table.name.map(lambda x: 'Faizah binte Haji Ahmad Jamal' if x == 'JAMAL BIN IDRIS' else x) 
reference_table['party']= reference_table.party.map(lambda x: 'Nominated Member of Parliament' if x == 'Pertubuhan Kebangsaan Melayu Singapura'else x)

# %%
party_speeches = reference_table.groupby(by=['party','year']).sum().reset_index()

# %%
count_mp_year = reference_table[['name','party','year']].drop_duplicates().groupby(by=['party','year']).count()

# %%
count_mp_year.reset_index(inplace=True)

# %%
avg_speech_length = party_speeches[party_speeches['speech_mins']>10][['party','year','speech_mins']]

# %%
avg_speech_length.head()
# Out:
#                             party  year  speech_mins
# 1  Nominated Member of Parliament  2009       408.99
# 2  Nominated Member of Parliament  2010       188.40
# 3  Nominated Member of Parliament  2011       145.06
# 4  Nominated Member of Parliament  2012       301.66
# 5  Nominated Member of Parliament  2013       346.85

# %%
avg_speech_length['key'] =  avg_speech_length[['party','year']].apply(lambda x : str(x.party) + str(x.year),axis=1)

# %%
avg_speech_length.head()
# Out:
#                             party  year  speech_mins  \
# 1  Nominated Member of Parliament  2009       408.99
# 2  Nominated Member of Parliament  2010       188.40
# 3  Nominated Member of Parliament  2011       145.06
# 4  Nominated Member of Parliament  2012       301.66
# 5  Nominated Member of Parliament  2013       346.85
#
#                                   key
# 1  Nominated Member of Parliament2009
# 2  Nominated Member of Parliament2010
# 3  Nominated Member of Parliament2011
# 4  Nominated Member of Parliament2012
# 5  Nominated Member of Parliament2013

# %%
count_mp_year['key'] = count_mp_year[['party','year']].apply(lambda x : str(x.party) + str(x.year),axis=1)

# %%
count_mp_year.head()
# Out:
#                             party  year  name  \
# 0                Barisan Sosialis  2009     1
# 1  Nominated Member of Parliament  2009    13
# 2  Nominated Member of Parliament  2010     7
# 3  Nominated Member of Parliament  2011     9
# 4  Nominated Member of Parliament  2012    11
#
#                                   key
# 0                Barisan Sosialis2009
# 1  Nominated Member of Parliament2009
# 2  Nominated Member of Parliament2010
# 3  Nominated Member of Parliament2011
# 4  Nominated Member of Parliament2012

# %%
merged_counts = avg_speech_length.merge(count_mp_year,on='key',how='left')[['party_x','year_x','speech_mins','name']]

# %%
merged_counts.columns
# Out:
# Index(['party_x', 'year_x', 'speech_mins', 'name'], dtype='object')

# %%
merged_counts.rename(columns = {'party_x':'party','year_x':'year', 'name':'member_count'},inplace=True)

# %%
merged_counts.head(3)
# Out:
#                             party  year  speech_mins  member_count
# 0  Nominated Member of Parliament  2009       408.99            13
# 1  Nominated Member of Parliament  2010       188.40             7
# 2  Nominated Member of Parliament  2011       145.06             9

# %%
merged_counts.to_csv('dumps/party_speechtime.csv')

# %% [markdown]
# ## Append Speech meta-data with party information

# %%
sanctioned_list = ['National Solidarity Party','Nominated Member of Parliament',
                  "People's Action Party","Presidential Office","Singapore People's Party",
                  "Workers' Party"]


def add_party(chunks):
    for val in chunks:
        try:
            if val['entity'] != '' or val['entity'] != [')','.']:
                try:
                    matched_idx = process.extractOne(val['entity'],consolidated_names.name,scorer=fuzz.token_set_ratio, score_cutoff=80)[2]
                    party = consolidated_names.iloc[matched_idx].party
                    if party in sanctioned_list:
                        val['party'] = party
                    else:
                        val['party'] = "NA"
                except TypeError:
                    val['party'] = "NA"
                    pass
            else:
                pass
        except KeyError:
            pass
    return chunks

# %%
add_party(mongo_df.iloc[8300].parsed_convo)
# Out:
# [{'content': 'The Leader of the House (Dr Ng Eng Hen): Mr Deputy Speaker, Sir, can I seek your consent to move that the debate be now adjourned?',
#   'type': 'response',
#   'entity': 'The Leader of the House (Dr Ng Eng Hen)',
#   'party': "People's Action Party"},
#  {'content': 'Mr Deputy Speaker: You have my consent.Resolved,That the debate be now adjourned. – [Dr Ng Eng Hen].',
#   'type': 'response',
#   'entity': 'Mr Deputy Speaker',
#   'party': 'NA'},
#  {'content': 'Mr Deputy Speaker: Dr Lam Pin Min, resumption of debate, what day?',
#   'type': 'response',
#   'entity': 'Mr Deputy Speaker',
#   'party': 'NA'},
#  {'content': 'Dr Lam Pin Min (Sengkang West): Tomorrow, Sir.',
#   'type': 'response',
#   'entity': 'Dr Lam Pin Min (Sengkang West)',
#   'party': "People's Action Party"},
#  {'content': 'Mr Deputy Speaker: So be it.',
#   'type': 'response',
#   'entity': 'Mr Deputy Speaker',
#   'party': 'NA'},
#  {'type': 'compiled_responses',
#   'content': '\n\nMr Deputy Speaker: You have my consent.Resolved,That the debate be now adjourned. – [Dr Ng Eng Hen].\n\nMr Deputy Speaker: Dr Lam Pin Min, resumption of debate, what day?\n\nDr Lam Pin Min (Sengkang West): Tomorrow, Sir.\n\nMr Deputy Speaker: So be it.'}]

# %%
# %time mongo_df.chunks = mongo_df.parsed_convo.map(add_party)

# %%
mongo_df.iloc[30].parsed_convo
# Out:
# [{'content': 'Ms Anthea Ong asked the Minister for Health (a) what is the percentage of persons over 65 years of age who want to age in place; and (b) what is the percentage of care-givers of persons over the age of 65 years who want to see their care recipients age in place.',
#   'type': 'question',
#   'entity': 'Ms Anthea Ong',
#   'party': 'Nominated Member of Parliament'},
#  {'content': 'Mr Gan Kim Yong: Most seniors prefer to age in place for as long as they can, within communities which they are familiar with, and supported by their loved ones. A study by the Duke-NUS Centre for Ageing Research and Education (CARE) conducted from 2011 to 2012 found that 97.9% of persons aged 65 and above prefer to continue staying at home if they cannot live independently, supported by family, foreign domestic workers, or home care services. Only 2.1% of persons aged 65 and above preferred to move to a nursing home if they cannot live independently. We are not aware of corresponding data on the preferences of care-givers.',
#   'type': 'response',
#   'entity': 'Mr Gan Kim Yong',
#   'party': "People's Action Party"},
#  {'type': 'compiled_responses',
#   'content': '\n\nMr Gan Kim Yong: Most seniors prefer to age in place for as long as they can, within communities which they are familiar with, and supported by their loved ones. A study by the Duke-NUS Centre for Ageing Research and Education (CARE) conducted from 2011 to 2012 found that 97.9% of persons aged 65 and above prefer to continue staying at home if they cannot live independently, supported by family, foreign domestic workers, or home care services. Only 2.1% of persons aged 65 and above preferred to move to a nursing home if they cannot live independently. We are not aware of corresponding data on the preferences of care-givers.'}]

# %% [markdown]
# ## Updating our document DB with the information

# %%
from tqdm import tqdm

for row in tqdm(mongo_df.itertuples()):
    query = { "_id" : row._1 }
    value = { "$set": { "chunks": row.chunks,
                      "parsed_convo": row.parsed_convo } }
    articles.update_one(query,value)
# Out:
# 9531it [00:52, 180.82it/s]
